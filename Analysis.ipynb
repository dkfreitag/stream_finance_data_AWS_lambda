# %% [markdown]
# ### David Freitag
# STA 9760 - Big Data Technologies
# Project #3 - Extra Credit
# 5/16/21

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_results = pd.read_csv('results.csv')
df_results
# Out:
#     name        high                         ts  hour
# 0   BYND  104.709999  2021-05-11 09:55:00-04:00     9
# 1   BYND  106.460999  2021-05-11 10:55:00-04:00    10
# 2   BYND  107.695000  2021-05-11 11:55:00-04:00    11
# 3   BYND  108.839996  2021-05-11 12:55:00-04:00    12
# 4   BYND  110.660004  2021-05-11 13:45:00-04:00    13
# ..   ...         ...                        ...   ...
# 65   TTD  494.500000  2021-05-11 11:50:00-04:00    11
# 66   TTD  491.440002  2021-05-11 12:00:00-04:00    12
# 67   TTD  497.220001  2021-05-11 13:35:00-04:00    13
# 68   TTD  508.669891  2021-05-11 14:45:00-04:00    14
# 69   TTD  515.531311  2021-05-11 15:50:00-04:00    15
#
# [70 rows x 4 columns]

# %%
stock_list = ['FB', 'SHOP', 'BYND', 'NFLX', 'PINS', 'SQ', 'TTD', 'OKTA', 'SNAP', 'DDOG']
for stock in stock_list:
    fig = plt.figure(figsize=(10,6))
    sns.lineplot(data=df_results[df_results.name == stock], x='hour', y='high')
    plt.title(stock)
    plt.show()

# %%
fig = plt.figure(figsize=(10,6))
sns.lineplot(data=df_results[(df_results.name == 'SQ') | (df_results.name == 'OKTA')],
             x='hour', y='high', hue='name')
# Out:
# <AxesSubplot:xlabel='hour', ylabel='high'>

# %%
fig = plt.figure(figsize=(10,6))
sns.lineplot(data=df_results[(df_results.name == 'NFLX') | (df_results.name == 'TTD')],
             x='hour', y='high', hue='name')
# Out:
# <AxesSubplot:xlabel='hour', ylabel='high'>

# %%
fig = plt.figure(figsize=(10,6))
sns.lineplot(data=df_results[(df_results.name == 'SNAP') | (df_results.name == 'PINS')],
             x='hour', y='high', hue='name')
# Out:
# <AxesSubplot:xlabel='hour', ylabel='high'>
